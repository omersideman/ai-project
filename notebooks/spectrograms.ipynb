# %% [markdown]
# # Preparing Audio Files for CNN

# %% [markdown]
# For the cnn we want to input a the mel spectrograms of audio files, cropped to the first minute.
#
# Spectrograms are a way to visually represent a signal's loudness, or amplitude, as it varies over time at different frequencies. The horizontal axis is time, the vertical axis is frequency, and the color is amplitude. It is calculated using the fast Fourier transform on short time windows of the signal and transforming the vertical axis (frequency) to log scale and the colored axis (amplitude) to decibals.
#
# Now, what about the "mel" part? Humans are better at detecting differences in lower frequencies than higher frequencies. The mel scale transforms the frequency scale such that sounds at equal distances from each other also sound equal in distance. A mel spectrogram is a spectrogram where the frequencies are converted to the mel scale.

# %% [markdown]
# #### Imports

# %%
import sys
sys.path.append("..")
import warnings
import pandas as pd
from IPython.display import Audio
import matplotlib.pyplot as plt
import librosa.display
import numpy as np
from PIL import Image
import librosa
from tqdm import tqdm
from src.utils.audio_utils import find_chorus
from src.utils.plot_utils import plot_audio_wave, plot_spectrogram
from src.utils.spectrograms import (
    save_spectrogram,
    get_mel_spectrogram,
    get_spectrograms,
)

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Toy Example

# %%
AUDIO_DIR = "../data/audio_wav/"
CSV_PATH = "../data/audio_features.csv"
SPEC_DIR = "../data/spectrograms/"
SR = 22050

# example_audio_path = AUDIO_DIR + "7ya7Jv4hJ9W0Baz7h9nL7E.wav"

# %% [markdown]
# ### Extracting an Audio Signal
#
# First we will load a demo track (Dance of the Sugar Plum Fairy by Tchaikovsky) and plot the waveform.

# %%
y, sr = librosa.load(librosa.ex('nutcracker'))
plot_audio_wave(y)

# %% [markdown]
# ### Computing Spectrogram
#
# Spectrograms are a way to visually represent a signal's loudness, or amplitude, as it varies over time at different frequencies. The horizontal axis is time, the vertical axis is frequency, and the color is amplitude. It is calculated using the fast Fourier transform on short time windows of the signal.

# %%
plot_spectrogram(y, SR, mel=False)
# Out:
# Mel Spectrogram shape: (1025, 5163)

# %% [markdown]
# ### Mel Spectrograms
#
# Spectrograms are a way to visually represent a signal's loudness, or amplitude, as it varies over time at different frequencies. The horizontal axis is time, the vertical axis is frequency, and the color is amplitude. It is calculated using the fast Fourier transform on short time windows of the signal and transforming the vertical axis (frequency) to log scale and the colored axis (amplitude) to decibals. Now, what about the "mel" part? Humans are better at detecting differences in lower frequencies than higher frequencies. The mel scale transforms the frequency scale such that sounds at equal distances from each other also sound equal in distance. A mel spectrogram is a spectrogram where the frequencies are converted to the mel scale.
#
# This is what will be the input to the cnn!

# %%
plot_spectrogram(y, SR, mel=True)
# Out:
# Mel Spectrogram shape: (128, 5163)

# %% [markdown]
# #### Downloading mel spectrogram as a png image

# %%
spec = get_mel_spectrogram(example_audio_path, offset=0, duration=60, hop_length=1024)
out_path = "../data/examples/mel_spectrogram.png"
save_spectrogram(spec, out_path)

# display image
img = Image.open(out_path)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1292x128>

# %% [markdown]
# lower resolution (compressed)

# %%
spec = get_mel_spectrogram(example_audio_path, offset=0, duration=60, hop_length=2048)
out_path = "../data/examples/mel_spectrogram_low.png"
save_spectrogram(spec, out_path)

# display image
img = Image.open(out_path)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=646x128>

# %% [markdown]
# ### Saving Many Mel Spectrograms as Images

# %% [markdown]
# Starting with the 500 most and least viral songs, across different combinations of settings

# %%
def many_spectrograms(top_or_bottom, res, duration, num_tracks, out_dir, chorus):
    # get length of csv
    df = pd.read_csv(CSV_PATH)
    num_tracks = len(df)
    start_index = 0 if top_or_bottom == "top" else num_tracks-500
    end_index = 500 if top_or_bottom == "top" else num_tracks-1

    get_spectrograms(AUDIO_DIR, CSV_PATH, out_dir, duration, start_index, end_index, res, chorus)

# %% [markdown]
# downloading spectrograms for all combinations

# %%
num_tracks = 500

# for res in ["low", "high"]:
#     for duration in [60, 30]:
#         for virality in ["top", "bottom"]:
#             out_dir = f"../data/spectrograms/{res}_{duration}_{num_tracks}/{virality}/"
#             many_spectrograms(virality, res, duration, num_tracks, out_dir, chorus=False)

# %% [markdown]
# do the same thing but with the song chorus instead of the track beginning

# %%
# example
chorus_start = find_chorus(example_audio_path, duration = 30)
y, sr = librosa.load(example_audio_path, offset=chorus_start, sr=SR, mono=True, duration=30) # type: ignore

plot_audio_wave(y)
# Out:
# Best chorus found at 1 min 4.27 sec

# %%
plot_spectrogram(y, sr)
# Out:
# Mel Spectrogram shape: (128, 1292)

# %%
for res in ["low", "high"]:
    for duration in [15, 30]:
        for virality in ["top", "bottom"]:
            out_dir = f"../data/spectrograms/ch_{res}_{duration}_{num_tracks}/{virality}/"
            many_spectrograms(virality, res, duration, num_tracks, out_dir, chorus=True)
# Out:
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 61 of 3932
# Best chorus found at 2 min 5.91 sec
# Processing track 62 of 3932
# Best chorus found at 1 min 27.61 sec
# Processing track 63 of 3932
# Best chorus found at 1 min 42.31 sec
# Processing track 64 of 3932
# Best chorus found at 2 min 42.35 sec
# Processing track 65 of 3932
# Best chorus found at 1 min 21.12 sec
# Processing track 66 of 3932
# Best chorus found at 0 min 54.24 sec
# Processing track 67 of 3932
# Best chorus found at 2 min 49.34 sec
# Processing track 68 of 3932
# Best chorus found at 1 min 19.29 sec
# Processing track 69 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 70 of 3932
# Best chorus found at 2 min 56.62 sec
# Processing track 71 of 3932
# Best chorus found at 2 min 22.23 sec
# Processing track 72 of 3932
# Best chorus found at 2 min 3.68 sec
# Processing track 73 of 3932
# Best chorus found at 2 min 1.57 sec
# Processing track 74 of 3932
# Best chorus found at 3 min 12.34 sec
# Processing track 75 of 3932
# Best chorus found at 0 min 19.12 sec
# Processing track 76 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 77 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 78 of 3932
# Best chorus found at 3 min 1.56 sec
# Processing track 79 of 3932
# Best chorus found at 2 min 54.32 sec
# Processing track 80 of 3932
# Best chorus found at 1 min 20.56 sec
# Processing track 81 of 3932
# Best chorus found at 3 min 9.66 sec
# Processing track 82 of 3932
# Best chorus found at 0 min 50.34 sec
# Processing track 83 of 3932
# Best chorus found at 1 min 29.16 sec
# Processing track 84 of 3932
# Best chorus found at 1 min 12.40 sec
# Processing track 85 of 3932
# Best chorus found at 1 min 17.58 sec
# Processing track 86 of 3932
# Best chorus found at 2 min 35.61 sec
# Processing track 87 of 3932
# Best chorus found at 2 min 15.94 sec
# Processing track 88 of 3932
# Best chorus found at 1 min 4.57 sec
# Processing track 89 of 3932
# Best chorus found at 2 min 10.96 sec
# Processing track 90 of 3932
# Best chorus found at 1 min 45.44 sec
# Processing track 91 of 3932
# Best chorus found at 1 min 9.41 sec
# Processing track 92 of 3932
# Best chorus found at 2 min 27.12 sec
# Processing track 93 of 3932
# Best chorus found at 3 min 2.71 sec
# Processing track 94 of 3932
# Best chorus found at 1 min 9.08 sec
# Processing track 95 of 3932
# Best chorus found at 3 min 9.59 sec
# Processing track 96 of 3932
# Best chorus found at 2 min 33.21 sec
# Processing track 97 of 3932
# Best chorus found at 2 min 51.71 sec
# Processing track 98 of 3932
# Best chorus found at 2 min 51.05 sec
# Processing track 99 of 3932
# Best chorus found at 1 min 33.94 sec
# Processing track 100 of 3932
# Best chorus found at 1 min 29.14 sec
# Processing track 101 of 3932
# Best chorus found at 2 min 5.76 sec
# Processing track 102 of 3932
# Best chorus found at 2 min 22.21 sec
# Processing track 103 of 3932
# Best chorus found at 2 min 33.52 sec
# Processing track 104 of 3932
# Best chorus found at 1 min 59.97 sec
# Processing track 105 of 3932
# Best chorus found at 2 min 47.00 sec
# Processing track 106 of 3932
# Best chorus found at 2 min 20.94 sec
# Processing track 107 of 3932
# Best chorus found at 3 min 23.78 sec
# Processing track 108 of 3932
# Best chorus found at 0 min 57.77 sec
# Processing track 109 of 3932
# Best chorus found at 2 min 23.74 sec
# Processing track 110 of 3932
# Best chorus found at 1 min 3.07 sec
# Processing track 111 of 3932
# Best chorus found at 2 min 50.68 sec
# Processing track 112 of 3932
# Best chorus found at 2 min 47.63 sec
# Processing track 113 of 3932
# Best chorus found at 2 min 16.90 sec
# Processing track 114 of 3932
# Best chorus found at 2 min 3.90 sec
# Processing track 115 of 3932
# Best chorus found at 4 min 25.41 sec
# Processing track 116 of 3932
# Best chorus found at 2 min 43.55 sec
# Processing track 117 of 3932
# Best chorus found at 1 min 7.57 sec
# Processing track 118 of 3932
# Best chorus found at 2 min 54.05 sec
# Processing track 119 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 120 of 3932
# Best chorus found at 2 min 47.99 sec
# Processing track 121 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 122 of 3932
# Best chorus found at 3 min 18.50 sec
# Processing track 123 of 3932
# Best chorus found at 2 min 12.74 sec
# Processing track 124 of 3932
# Best chorus found at 2 min 4.61 sec
# Processing track 125 of 3932
# Best chorus found at 2 min 45.03 sec
# Processing track 126 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 127 of 3932
# Best chorus found at 1 min 3.85 sec
# Processing track 128 of 3932
# Best chorus found at 2 min 39.91 sec
# Processing track 129 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 130 of 3932
# Best chorus found at 2 min 9.62 sec
# Processing track 131 of 3932
# Best chorus found at 2 min 4.57 sec
# Processing track 132 of 3932
# Best chorus found at 3 min 21.66 sec
# Processing track 133 of 3932
# Best chorus found at 1 min 55.87 sec
# Processing track 134 of 3932
# Best chorus found at 1 min 28.32 sec
# Processing track 135 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 136 of 3932
# Best chorus found at 1 min 20.19 sec
# Processing track 137 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 138 of 3932
# Best chorus found at 2 min 8.69 sec
# Processing track 139 of 3932
# Best chorus found at 1 min 54.05 sec
# Processing track 140 of 3932
# Best chorus found at 3 min 50.86 sec
# Processing track 141 of 3932
# Best chorus found at 2 min 4.76 sec
# Processing track 142 of 3932
# Best chorus found at 0 min 42.88 sec
# Processing track 143 of 3932
# Best chorus found at 1 min 15.97 sec
# Processing track 144 of 3932
# Best chorus found at 1 min 46.78 sec
# Processing track 145 of 3932
# Best chorus found at 1 min 32.09 sec
# Processing track 146 of 3932
# Best chorus found at 1 min 4.62 sec
# Processing track 147 of 3932
# Best chorus found at 2 min 56.02 sec
# Processing track 148 of 3932
# Best chorus found at 2 min 16.53 sec
# Processing track 149 of 3932
# Best chorus found at 2 min 17.20 sec
# Processing track 150 of 3932
# Best chorus found at 1 min 56.21 sec
# Processing track 151 of 3932
# Best chorus found at 2 min 35.60 sec
# Processing track 152 of 3932
# Best chorus found at 0 min 48.80 sec
# Processing track 153 of 3932
# Best chorus found at 1 min 23.91 sec
# Processing track 154 of 3932
# Best chorus found at 2 min 31.17 sec
# Processing track 155 of 3932
# Best chorus found at 2 min 5.48 sec
# Processing track 156 of 3932
# Best chorus found at 1 min 55.54 sec
# Processing track 157 of 3932
# Best chorus found at 2 min 50.80 sec
# Processing track 158 of 3932
# Best chorus found at 2 min 15.30 sec
# Processing track 159 of 3932
# Best chorus found at 3 min 23.89 sec
# Processing track 160 of 3932
# Best chorus found at 2 min 14.23 sec
# Processing track 161 of 3932
# Best chorus found at 1 min 39.69 sec
# Processing track 162 of 3932
# Best chorus found at 1 min 52.94 sec
# Processing track 163 of 3932
# Best chorus found at 2 min 8.25 sec
# Processing track 164 of 3932
# Best chorus found at 2 min 19.64 sec
# Processing track 165 of 3932
# Best chorus found at 1 min 20.96 sec
# Processing track 166 of 3932
# Best chorus found at 1 min 11.81 sec
# Processing track 167 of 3932
# Best chorus found at 2 min 1.97 sec
# Processing track 168 of 3932
# Best chorus found at 2 min 19.76 sec
# Processing track 169 of 3932
# Best chorus found at 1 min 28.58 sec
# Processing track 170 of 3932
# Best chorus found at 1 min 4.26 sec
# Processing track 171 of 3932
# Best chorus found at 3 min 17.52 sec
# Processing track 172 of 3932
# Best chorus found at 1 min 53.05 sec
# Processing track 173 of 3932
# Best chorus found at 1 min 26.93 sec
# Processing track 174 of 3932
# Best chorus found at 1 min 48.06 sec
# Processing track 175 of 3932
# Best chorus found at 1 min 2.73 sec
# Processing track 176 of 3932
# Best chorus found at 2 min 28.01 sec
# Processing track 177 of 3932
# Best chorus found at 2 min 41.61 sec
# Processing track 178 of 3932
# Best chorus found at 1 min 20.80 sec
# Processing track 179 of 3932
# Best chorus found at 1 min 29.54 sec
# Processing track 180 of 3932
# Best chorus found at 1 min 36.94 sec
# Processing track 181 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 182 of 3932
# Best chorus found at 2 min 46.52 sec
# Processing track 183 of 3932
# Best chorus found at 1 min 47.34 sec
# Processing track 184 of 3932
# Best chorus found at 2 min 4.02 sec
# Processing track 185 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 186 of 3932
# Best chorus found at 2 min 3.84 sec
# Processing track 187 of 3932
# Best chorus found at 3 min 5.46 sec
# Processing track 188 of 3932
# Best chorus found at 1 min 44.56 sec
# Processing track 189 of 3932
# Best chorus found at 2 min 54.32 sec
# Processing track 190 of 3932
# WARNING: problem with finding chorus: [Errno 2] No such file or directory: '../data/audio_wav/1EcQvRklwuO1XAOgYaXkyz.wav', skipping...
# WARNING: file not found: ../data/audio_wav/1EcQvRklwuO1XAOgYaXkyz.wav, skipping...
# Processing track 191 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 192 of 3932
# Best chorus found at 1 min 24.30 sec
# Processing track 193 of 3932
# Best chorus found at 1 min 22.43 sec
# Processing track 194 of 3932
# Best chorus found at 0 min 56.66 sec
# Processing track 195 of 3932
# Best chorus found at 2 min 28.94 sec
# Processing track 196 of 3932
# Best chorus found at 2 min 42.54 sec
# Processing track 197 of 3932
# Best chorus found at 3 min 21.32 sec
# Processing track 198 of 3932
# Best chorus found at 2 min 6.28 sec
# Processing track 199 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 200 of 3932
# Best chorus found at 2 min 28.79 sec
# Processing track 201 of 3932
# Best chorus found at 1 min 51.03 sec
# Processing track 202 of 3932
# Best chorus found at 1 min 34.55 sec
# Processing track 203 of 3932
# Best chorus found at 4 min 27.75 sec
# Processing track 204 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 205 of 3932
# Best chorus found at 1 min 49.78 sec
# Processing track 206 of 3932
# Best chorus found at 3 min 3.23 sec
# Processing track 207 of 3932
# Best chorus found at 1 min 53.50 sec
# Processing track 208 of 3932
# Best chorus found at 2 min 40.49 sec
# Processing track 209 of 3932
# Best chorus found at 1 min 58.51 sec
# Processing track 210 of 3932
# Best chorus found at 1 min 1.86 sec
# Processing track 211 of 3932
# Best chorus found at 3 min 11.11 sec
# Processing track 212 of 3932
# Best chorus found at 2 min 4.91 sec
# Processing track 213 of 3932
# Best chorus found at 1 min 37.11 sec
# Processing track 214 of 3932
# Best chorus found at 1 min 22.82 sec
# Processing track 215 of 3932
# Best chorus found at 0 min 57.37 sec
# Processing track 216 of 3932
# Best chorus found at 1 min 59.23 sec
# Processing track 217 of 3932
# Best chorus found at 4 min 38.82 sec
# Processing track 218 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 219 of 3932
# Best chorus found at 2 min 0.08 sec
# Processing track 220 of 3932
# Best chorus found at 1 min 55.49 sec
# Processing track 221 of 3932
# Best chorus found at 1 min 58.81 sec
# Processing track 222 of 3932
# Best chorus found at 2 min 19.47 sec
# Processing track 223 of 3932
# Best chorus found at 2 min 4.61 sec
# Processing track 224 of 3932
# Best chorus found at 2 min 1.67 sec
# Processing track 225 of 3932
# Best chorus found at 1 min 33.74 sec
# Processing track 226 of 3932
# Best chorus found at 2 min 51.83 sec
# Processing track 227 of 3932
# Best chorus found at 1 min 59.03 sec
# Processing track 228 of 3932
# Best chorus found at 2 min 44.92 sec
# Processing track 229 of 3932
# Best chorus found at 2 min 45.40 sec
# Processing track 230 of 3932
# Best chorus found at 2 min 7.39 sec
# Processing track 231 of 3932
# Best chorus found at 1 min 20.37 sec
# Processing track 232 of 3932
# Best chorus found at 2 min 3.98 sec
# Processing track 233 of 3932
# Best chorus found at 2 min 30.98 sec
# Processing track 234 of 3932
# Best chorus found at 2 min 58.03 sec
# Processing track 235 of 3932
# Best chorus found at 2 min 2.97 sec
# Processing track 236 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 237 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 238 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 239 of 3932
# Best chorus found at 2 min 14.62 sec
# Processing track 240 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 241 of 3932
# Best chorus found at 3 min 6.23 sec
# Processing track 242 of 3932
# Best chorus found at 3 min 8.17 sec
# Processing track 243 of 3932
# Best chorus found at 1 min 43.61 sec
# Processing track 244 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 245 of 3932
# Best chorus found at 2 min 25.38 sec
# Processing track 246 of 3932
# Best chorus found at 1 min 11.11 sec
# Processing track 247 of 3932
# Best chorus found at 1 min 30.03 sec
# Processing track 248 of 3932
# Best chorus found at 1 min 47.33 sec
# Processing track 249 of 3932
# Best chorus found at 1 min 24.50 sec
# Processing track 250 of 3932
# Best chorus found at 2 min 25.15 sec
# Processing track 251 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 252 of 3932
# Best chorus found at 0 min 57.19 sec
# Processing track 253 of 3932
# Best chorus found at 2 min 45.24 sec
# Processing track 254 of 3932
# Best chorus found at 1 min 33.59 sec
# Processing track 255 of 3932
# Best chorus found at 2 min 44.46 sec
# Processing track 256 of 3932
# Best chorus found at 1 min 36.78 sec
# Processing track 257 of 3932
# Best chorus found at 2 min 41.24 sec
# Processing track 258 of 3932
# Best chorus found at 1 min 34.29 sec
# Processing track 259 of 3932
# Best chorus found at 1 min 11.67 sec
# Processing track 260 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 261 of 3932
# Best chorus found at 3 min 42.35 sec
# Processing track 262 of 3932
# Best chorus found at 1 min 50.90 sec
# Processing track 263 of 3932
# Best chorus found at 2 min 50.31 sec
# Processing track 264 of 3932
# Best chorus found at 1 min 30.62 sec
# Processing track 265 of 3932
# Best chorus found at 2 min 41.76 sec
# Processing track 266 of 3932
# Best chorus found at 1 min 42.84 sec
# Processing track 267 of 3932
# Best chorus found at 3 min 31.72 sec
# Processing track 268 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 269 of 3932
# Best chorus found at 2 min 2.60 sec
# Processing track 270 of 3932
# Best chorus found at 3 min 44.72 sec
# Processing track 271 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 272 of 3932
# Best chorus found at 1 min 8.13 sec
# Processing track 273 of 3932
# Best chorus found at 2 min 43.58 sec
# Processing track 274 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# WARNING: file loading timed out for ../data/audio_wav/6RScVA1bXcmtXGD0wGyqXO.wav, skipping...
# Processing track 275 of 3932
# Best chorus found at 2 min 2.94 sec
# Processing track 276 of 3932
# Best chorus found at 2 min 10.00 sec
# Processing track 277 of 3932
# Best chorus found at 2 min 6.40 sec
# Processing track 278 of 3932
# Best chorus found at 3 min 47.14 sec
# Processing track 279 of 3932
# Best chorus found at 1 min 56.77 sec
# Processing track 280 of 3932
# Best chorus found at 1 min 46.20 sec
# Processing track 281 of 3932
# Best chorus found at 3 min 0.29 sec
# Processing track 282 of 3932
# Best chorus found at 3 min 44.65 sec
# Processing track 283 of 3932
# Best chorus found at 1 min 20.03 sec
# Processing track 284 of 3932
# Best chorus found at 2 min 39.90 sec
# Processing track 285 of 3932
# Best chorus found at 3 min 33.74 sec
# Processing track 286 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 287 of 3932
# Best chorus found at 1 min 33.58 sec
# Processing track 288 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 289 of 3932
# Best chorus found at 1 min 48.26 sec
# Processing track 290 of 3932
# Best chorus found at 2 min 7.41 sec
# Processing track 291 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 292 of 3932
# Best chorus found at 3 min 44.40 sec
# Processing track 293 of 3932
# Best chorus found at 1 min 40.64 sec
# Processing track 294 of 3932
# Best chorus found at 1 min 3.49 sec
# Processing track 295 of 3932
# Best chorus found at 2 min 10.33 sec
# Processing track 296 of 3932
# Best chorus found at 2 min 8.13 sec
# Processing track 297 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 298 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 299 of 3932
# Best chorus found at 2 min 0.93 sec
# Processing track 300 of 3932
# Best chorus found at 1 min 59.04 sec
# Processing track 301 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 302 of 3932
# Best chorus found at 2 min 55.17 sec
# Processing track 303 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 304 of 3932
# Best chorus found at 2 min 28.61 sec
# Processing track 305 of 3932
# Best chorus found at 3 min 9.25 sec
# Processing track 306 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 307 of 3932
# Best chorus found at 3 min 2.85 sec
# Processing track 308 of 3932
# Best chorus found at 2 min 14.42 sec
# Processing track 309 of 3932
# Best chorus found at 1 min 10.59 sec
# Processing track 310 of 3932
# Best chorus found at 1 min 49.19 sec
# Processing track 311 of 3932
# Best chorus found at 0 min 36.59 sec
# Processing track 312 of 3932
# Best chorus found at 3 min 19.80 sec
# Processing track 313 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 314 of 3932
# Best chorus found at 2 min 4.83 sec
# Processing track 315 of 3932
# Best chorus found at 2 min 32.43 sec
# Processing track 316 of 3932
# Best chorus found at 2 min 19.08 sec
# Processing track 317 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 318 of 3932
# Best chorus found at 1 min 24.28 sec
# Processing track 319 of 3932
# Best chorus found at 3 min 49.31 sec
# Processing track 320 of 3932
# Best chorus found at 4 min 16.13 sec
# Processing track 321 of 3932
# Best chorus found at 3 min 59.88 sec
# Processing track 322 of 3932
# Best chorus found at 1 min 37.86 sec
# Processing track 323 of 3932
# Best chorus found at 1 min 54.70 sec
# Processing track 324 of 3932
# Best chorus found at 1 min 59.19 sec
# Processing track 325 of 3932
# Best chorus found at 2 min 36.96 sec
# Processing track 326 of 3932
# Best chorus found at 3 min 4.76 sec
# Processing track 327 of 3932
# Best chorus found at 1 min 42.45 sec
# Processing track 328 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 329 of 3932
# Best chorus found at 1 min 55.51 sec
# Processing track 330 of 3932
# Best chorus found at 0 min 51.96 sec
# Processing track 331 of 3932
# Best chorus found at 4 min 20.76 sec
# Processing track 332 of 3932
# Best chorus found at 2 min 59.51 sec
# Processing track 333 of 3932
# Best chorus found at 0 min 56.57 sec
# Processing track 334 of 3932
# Best chorus found at 3 min 19.94 sec
# Processing track 335 of 3932
# Best chorus found at 2 min 33.81 sec
# Processing track 336 of 3932
# Best chorus found at 2 min 17.42 sec
# Processing track 337 of 3932
# Best chorus found at 3 min 15.86 sec
# Processing track 338 of 3932
# Best chorus found at 3 min 6.23 sec
# Processing track 339 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 340 of 3932
# Best chorus found at 1 min 34.89 sec
# Processing track 341 of 3932
# Best chorus found at 2 min 32.80 sec
# Processing track 342 of 3932
# Best chorus found at 3 min 49.23 sec
# Processing track 343 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 344 of 3932
# Best chorus found at 2 min 44.51 sec
# Processing track 345 of 3932
# Best chorus found at 1 min 43.40 sec
# Processing track 346 of 3932
# Best chorus found at 1 min 42.66 sec
# Processing track 347 of 3932
# Best chorus found at 1 min 58.82 sec
# Processing track 348 of 3932
# Best chorus found at 1 min 55.12 sec
# Processing track 349 of 3932
# Best chorus found at 1 min 49.78 sec
# Processing track 350 of 3932
# Best chorus found at 1 min 43.84 sec
# Processing track 351 of 3932
# Best chorus found at 2 min 34.88 sec
# Processing track 352 of 3932
# Best chorus found at 1 min 46.60 sec
# Processing track 353 of 3932
# Best chorus found at 1 min 17.05 sec
# Processing track 354 of 3932
# Best chorus found at 2 min 19.48 sec
# Processing track 355 of 3932
# Best chorus found at 1 min 27.47 sec
# Processing track 356 of 3932
# Best chorus found at 3 min 24.26 sec
# Processing track 357 of 3932
# Best chorus found at 1 min 52.38 sec
# Processing track 358 of 3932
# Best chorus found at 1 min 0.33 sec
# Processing track 359 of 3932
# Best chorus found at 2 min 31.10 sec
# Processing track 360 of 3932
# Best chorus found at 3 min 27.41 sec
# Processing track 361 of 3932
# Best chorus found at 1 min 23.90 sec
# Processing track 362 of 3932
# Best chorus found at 1 min 36.76 sec
# Processing track 363 of 3932
# Best chorus found at 2 min 52.75 sec
# Processing track 364 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 365 of 3932
# Best chorus found at 2 min 49.69 sec
# Processing track 366 of 3932
# Best chorus found at 1 min 12.60 sec
# Processing track 367 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 368 of 3932
# Best chorus found at 2 min 20.99 sec
# Processing track 369 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 370 of 3932
# Best chorus found at 3 min 8.54 sec
# Processing track 371 of 3932
# Best chorus found at 0 min 46.77 sec
# Processing track 372 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 373 of 3932
# Best chorus found at 4 min 14.12 sec
# Processing track 374 of 3932
# Best chorus found at 2 min 17.40 sec
# Processing track 375 of 3932
# Best chorus found at 2 min 41.54 sec
# Processing track 376 of 3932
# Best chorus found at 0 min 37.30 sec
# Processing track 377 of 3932
# Best chorus found at 2 min 19.62 sec
# Processing track 378 of 3932
# Best chorus found at 1 min 53.97 sec
# Processing track 379 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 380 of 3932
# Best chorus found at 1 min 56.10 sec
# Processing track 381 of 3932
# Best chorus found at 1 min 48.44 sec
# Processing track 382 of 3932
# Best chorus found at 3 min 31.14 sec
# Processing track 383 of 3932
# Best chorus found at 0 min 48.48 sec
# Processing track 384 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 385 of 3932
# Best chorus found at 2 min 17.53 sec
# Processing track 386 of 3932
# Best chorus found at 2 min 22.60 sec
# Processing track 387 of 3932
# Best chorus found at 3 min 24.15 sec
# Processing track 388 of 3932
# Best chorus found at 1 min 55.35 sec
# Processing track 389 of 3932
# Best chorus found at 3 min 19.20 sec
# Processing track 390 of 3932
# Best chorus found at 1 min 54.34 sec
# Processing track 391 of 3932
# Best chorus found at 1 min 10.77 sec
# Processing track 392 of 3932
# Best chorus found at 1 min 46.51 sec
# Processing track 393 of 3932
# Best chorus found at 2 min 14.26 sec
# Processing track 394 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 395 of 3932
# Best chorus found at 3 min 21.70 sec
# Processing track 396 of 3932
# Best chorus found at 1 min 54.03 sec
# Processing track 397 of 3932
# Best chorus found at 3 min 6.50 sec
# Processing track 398 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 399 of 3932
# Best chorus found at 2 min 44.86 sec
# Processing track 400 of 3932
# Best chorus found at 1 min 49.14 sec
# Processing track 401 of 3932
# Best chorus found at 2 min 1.67 sec
# Processing track 402 of 3932
# Best chorus found at 2 min 55.69 sec
# Processing track 403 of 3932
# Best chorus found at 2 min 29.65 sec
# Processing track 404 of 3932
# Best chorus found at 1 min 46.72 sec
# Processing track 405 of 3932
# Best chorus found at 2 min 22.21 sec
# Processing track 406 of 3932
# Best chorus found at 1 min 9.05 sec
# Processing track 407 of 3932
# Best chorus found at 2 min 44.54 sec
# Processing track 408 of 3932
# Best chorus found at 2 min 43.79 sec
# Processing track 409 of 3932
# Best chorus found at 2 min 53.23 sec
# Processing track 410 of 3932
# Best chorus found at 2 min 8.62 sec
# Processing track 411 of 3932
# Best chorus found at 2 min 14.95 sec
# Processing track 412 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 413 of 3932
# Best chorus found at 0 min 25.62 sec
# Processing track 414 of 3932
# Best chorus found at 2 min 57.73 sec
# Processing track 415 of 3932
# Best chorus found at 2 min 59.33 sec
# Processing track 416 of 3932
# Best chorus found at 2 min 57.13 sec
# Processing track 417 of 3932
# Best chorus found at 1 min 27.21 sec
# Processing track 418 of 3932
# Best chorus found at 2 min 25.95 sec
# Processing track 419 of 3932
# Best chorus found at 4 min 12.52 sec
# Processing track 420 of 3932
# Best chorus found at 2 min 33.95 sec
# Processing track 421 of 3932
# Best chorus found at 1 min 15.60 sec
# Processing track 422 of 3932
# Best chorus found at 2 min 5.57 sec
# Processing track 423 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 424 of 3932
# WARNING: problem with finding chorus: [Errno 2] No such file or directory: '../data/audio_wav/6kx8Hf1Udk4V0Ivq6zpoyG.wav', skipping...
# WARNING: file not found: ../data/audio_wav/6kx8Hf1Udk4V0Ivq6zpoyG.wav, skipping...
# Processing track 425 of 3932
# Best chorus found at 2 min 20.99 sec
# Processing track 426 of 3932
# Best chorus found at 1 min 44.87 sec
# Processing track 427 of 3932
# Best chorus found at 2 min 20.21 sec
# Processing track 428 of 3932
# Best chorus found at 1 min 47.30 sec
# Processing track 429 of 3932
# Best chorus found at 4 min 0.47 sec
# Processing track 430 of 3932
# Best chorus found at 0 min 33.61 sec
# Processing track 431 of 3932
# Best chorus found at 2 min 34.68 sec
# Processing track 432 of 3932
# Best chorus found at 1 min 14.12 sec
# Processing track 433 of 3932
# Best chorus found at 1 min 35.79 sec
# Processing track 434 of 3932
# Best chorus found at 2 min 5.36 sec
# Processing track 435 of 3932
# Best chorus found at 1 min 54.24 sec
# Processing track 436 of 3932
# Best chorus found at 0 min 57.58 sec
# Processing track 437 of 3932
# Best chorus found at 1 min 53.50 sec
# Processing track 438 of 3932
# Best chorus found at 1 min 55.81 sec
# Processing track 439 of 3932
# Best chorus found at 0 min 45.51 sec
# Processing track 440 of 3932
# Best chorus found at 2 min 12.15 sec
# Processing track 441 of 3932
# Best chorus found at 1 min 38.42 sec
# Processing track 442 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 443 of 3932
# Best chorus found at 2 min 20.02 sec
# Processing track 444 of 3932
# Best chorus found at 2 min 16.99 sec
# Processing track 445 of 3932
# Best chorus found at 2 min 58.57 sec
# Processing track 446 of 3932
# Best chorus found at 1 min 37.47 sec
# Processing track 447 of 3932
# Best chorus found at 1 min 15.16 sec
# Processing track 448 of 3932
# Best chorus found at 2 min 14.49 sec
# Processing track 449 of 3932
# Best chorus found at 2 min 3.83 sec
# Processing track 450 of 3932
# Best chorus found at 1 min 36.76 sec
# Processing track 451 of 3932
# Best chorus found at 2 min 9.84 sec
# Processing track 452 of 3932
# Best chorus found at 2 min 3.71 sec
# Processing track 453 of 3932
# Best chorus found at 0 min 56.98 sec
# Processing track 454 of 3932
# Best chorus found at 2 min 52.38 sec
# Processing track 455 of 3932
# Best chorus found at 2 min 0.82 sec
# Processing track 456 of 3932
# Best chorus found at 2 min 59.51 sec
# Processing track 457 of 3932
# Best chorus found at 2 min 16.97 sec
# Processing track 458 of 3932
# Best chorus found at 1 min 54.39 sec
# Processing track 459 of 3932
# Best chorus found at 3 min 16.45 sec
# Processing track 460 of 3932
# Best chorus found at 3 min 16.79 sec
# Processing track 461 of 3932
# Best chorus found at 0 min 38.99 sec
# Processing track 462 of 3932
# Best chorus found at 2 min 53.02 sec
# Processing track 463 of 3932
# Best chorus found at 1 min 48.57 sec
# Processing track 464 of 3932
# Best chorus found at 0 min 42.51 sec
# Processing track 465 of 3932
# Best chorus found at 2 min 44.47 sec
# Processing track 466 of 3932
# Best chorus found at 1 min 4.24 sec
# Processing track 467 of 3932
# Best chorus found at 1 min 17.81 sec
# Processing track 468 of 3932
# Best chorus found at 2 min 55.50 sec
# Processing track 469 of 3932
# Best chorus found at 1 min 38.45 sec
# Processing track 470 of 3932
# Best chorus found at 1 min 21.34 sec
# Processing track 471 of 3932
# Best chorus found at 3 min 7.76 sec
# Processing track 472 of 3932
# Best chorus found at 0 min 18.00 sec
# Processing track 473 of 3932
# Best chorus found at 1 min 5.57 sec
# Processing track 474 of 3932
# Best chorus found at 0 min 56.22 sec
# Processing track 475 of 3932
# Best chorus found at 1 min 29.33 sec
# Processing track 476 of 3932
# Best chorus found at 1 min 46.07 sec
# Processing track 477 of 3932
# Best chorus found at 2 min 53.87 sec
# Processing track 478 of 3932
# Best chorus found at 1 min 52.20 sec
# Processing track 479 of 3932
# Best chorus found at 1 min 33.39 sec
# Processing track 480 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 481 of 3932
# Best chorus found at 2 min 26.93 sec
# Processing track 482 of 3932
# Best chorus found at 2 min 31.58 sec
# Processing track 483 of 3932
# Best chorus found at 2 min 4.79 sec
# Processing track 484 of 3932
# Best chorus found at 1 min 58.14 sec
# Processing track 485 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 486 of 3932
# Best chorus found at 2 min 15.16 sec
# Processing track 487 of 3932
# Best chorus found at 1 min 17.07 sec
# Processing track 488 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 489 of 3932
# Best chorus found at 1 min 3.87 sec
# Processing track 490 of 3932
# Best chorus found at 3 min 36.97 sec
# Processing track 491 of 3932
# Best chorus found at 2 min 8.09 sec
# Processing track 492 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 493 of 3932
# Best chorus found at 2 min 50.65 sec
# Processing track 494 of 3932
# Best chorus found at 2 min 6.96 sec
# Processing track 495 of 3932
# Best chorus found at 3 min 1.40 sec
# Processing track 496 of 3932
# Best chorus found at 2 min 36.56 sec
# Processing track 497 of 3932
# Best chorus found at 1 min 17.63 sec
# Processing track 498 of 3932
# Best chorus found at 3 min 13.81 sec
# Processing track 499 of 3932
# Best chorus found at 1 min 49.38 sec
# Processing track 3432 of 3932
# Best chorus found at 2 min 24.45 sec
# Processing track 3433 of 3932
# Best chorus found at 1 min 38.57 sec
# Processing track 3434 of 3932
# Best chorus found at 1 min 59.81 sec
# Processing track 3435 of 3932
# Best chorus found at 2 min 23.96 sec
# Processing track 3436 of 3932
# Best chorus found at 2 min 2.90 sec
# Processing track 3437 of 3932
# Best chorus found at 2 min 46.78 sec
# Processing track 3438 of 3932
# Best chorus found at 2 min 12.56 sec
# Processing track 3439 of 3932
# Best chorus found at 1 min 33.40 sec
# Processing track 3440 of 3932
# Best chorus found at 1 min 50.82 sec
# Processing track 3441 of 3932
# Best chorus found at 2 min 30.91 sec
# Processing track 3442 of 3932
# Best chorus found at 3 min 7.12 sec
# Processing track 3443 of 3932
# Best chorus found at 2 min 54.24 sec
# Processing track 3444 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3445 of 3932
# Best chorus found at 3 min 8.88 sec
# Processing track 3446 of 3932
# Best chorus found at 2 min 58.47 sec
# Processing track 3447 of 3932
# Best chorus found at 2 min 20.43 sec
# Processing track 3448 of 3932
# Best chorus found at 1 min 40.05 sec
# Processing track 3449 of 3932
# Best chorus found at 3 min 44.36 sec
# Processing track 3450 of 3932
# Best chorus found at 1 min 58.33 sec
# Processing track 3451 of 3932
# Best chorus found at 1 min 19.69 sec
# Processing track 3452 of 3932
# Best chorus found at 2 min 43.84 sec
# Processing track 3453 of 3932
# Best chorus found at 3 min 24.44 sec
# Processing track 3454 of 3932
# Best chorus found at 2 min 55.32 sec
# Processing track 3455 of 3932
# Best chorus found at 3 min 32.47 sec
# Processing track 3456 of 3932
# Best chorus found at 2 min 11.63 sec
# Processing track 3457 of 3932
# Best chorus found at 3 min 0.74 sec
# Processing track 3458 of 3932
# Best chorus found at 3 min 28.89 sec
# Processing track 3459 of 3932
# Best chorus found at 5 min 13.30 sec
# Processing track 3460 of 3932
# Best chorus found at 1 min 17.26 sec
# Processing track 3461 of 3932
# Best chorus found at 3 min 2.01 sec
# Processing track 3462 of 3932
# Best chorus found at 1 min 18.58 sec
# Processing track 3463 of 3932
# Best chorus found at 2 min 41.98 sec
# Processing track 3464 of 3932
# Best chorus found at 1 min 20.43 sec
# Processing track 3465 of 3932
# Best chorus found at 1 min 26.93 sec
# Processing track 3466 of 3932
# Best chorus found at 2 min 4.95 sec
# Processing track 3467 of 3932
# Best chorus found at 2 min 18.49 sec
# Processing track 3468 of 3932
# Best chorus found at 2 min 14.67 sec
# Processing track 3469 of 3932
# Best chorus found at 2 min 39.75 sec
# Processing track 3470 of 3932
# Best chorus found at 3 min 3.79 sec
# Processing track 3471 of 3932
# Best chorus found at 2 min 32.09 sec
# Processing track 3472 of 3932
# Best chorus found at 2 min 41.31 sec
# Processing track 3473 of 3932
# Best chorus found at 3 min 12.78 sec
# Processing track 3474 of 3932
# Best chorus found at 0 min 43.28 sec
# Processing track 3475 of 3932
# Best chorus found at 1 min 50.90 sec
# Processing track 3476 of 3932
# Best chorus found at 2 min 43.40 sec
# Processing track 3477 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3478 of 3932
# Best chorus found at 2 min 20.89 sec
# Processing track 3479 of 3932
# Best chorus found at 1 min 36.96 sec
# Processing track 3480 of 3932
# Best chorus found at 3 min 25.02 sec
# Processing track 3481 of 3932
# Best chorus found at 1 min 3.89 sec
# Processing track 3482 of 3932
# Best chorus found at 2 min 52.68 sec
# Processing track 3483 of 3932
# Best chorus found at 2 min 9.66 sec
# Processing track 3484 of 3932
# Best chorus found at 3 min 15.20 sec
# Processing track 3485 of 3932
# Best chorus found at 2 min 36.37 sec
# Processing track 3486 of 3932
# Best chorus found at 1 min 7.58 sec
# Processing track 3487 of 3932
# Best chorus found at 2 min 5.70 sec
# Processing track 3488 of 3932
# Best chorus found at 1 min 21.18 sec
# Processing track 3489 of 3932
# Best chorus found at 1 min 6.99 sec
# Processing track 3490 of 3932
# Best chorus found at 0 min 39.38 sec
# Processing track 3491 of 3932
# Best chorus found at 2 min 17.79 sec
# Processing track 3492 of 3932
# Best chorus found at 2 min 53.43 sec
# Processing track 3493 of 3932
# Best chorus found at 1 min 57.00 sec
# Processing track 3494 of 3932
# Best chorus found at 5 min 45.76 sec
# Processing track 3495 of 3932
# Best chorus found at 1 min 53.24 sec
# Processing track 3496 of 3932
# Best chorus found at 2 min 41.05 sec
# Processing track 3497 of 3932
# Best chorus found at 2 min 25.45 sec
# Processing track 3498 of 3932
# Best chorus found at 2 min 4.80 sec
# Processing track 3499 of 3932
# Best chorus found at 1 min 2.93 sec
# Processing track 3500 of 3932
# Best chorus found at 3 min 1.59 sec
# Processing track 3501 of 3932
# Best chorus found at 4 min 5.01 sec
# Processing track 3502 of 3932
# Best chorus found at 1 min 21.14 sec
# Processing track 3503 of 3932
# Best chorus found at 2 min 5.39 sec
# Processing track 3504 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3505 of 3932
# Best chorus found at 2 min 10.33 sec
# Processing track 3506 of 3932
# Best chorus found at 3 min 17.46 sec
# Processing track 3507 of 3932
# Best chorus found at 2 min 4.09 sec
# Processing track 3508 of 3932
# Best chorus found at 2 min 21.18 sec
# Processing track 3509 of 3932
# Best chorus found at 2 min 48.05 sec
# Processing track 3510 of 3932
# Best chorus found at 3 min 55.87 sec
# Processing track 3511 of 3932
# Best chorus found at 2 min 36.04 sec
# Processing track 3512 of 3932
# Best chorus found at 2 min 49.52 sec
# Processing track 3513 of 3932
# Best chorus found at 2 min 33.58 sec
# Processing track 3514 of 3932
# Best chorus found at 1 min 27.47 sec
# Processing track 3515 of 3932
# Best chorus found at 2 min 31.46 sec
# Processing track 3516 of 3932
# Best chorus found at 2 min 1.42 sec
# Processing track 3517 of 3932
# Best chorus found at 4 min 6.01 sec
# Processing track 3518 of 3932
# Best chorus found at 3 min 16.53 sec
# Processing track 3519 of 3932
# Best chorus found at 3 min 30.95 sec
# Processing track 3520 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# WARNING: file loading timed out for ../data/audio_wav/1GTGv20ucjqPKXQGZ4Or24.wav, skipping...
# Processing track 3521 of 3932
# Best chorus found at 1 min 43.21 sec
# Processing track 3522 of 3932
# Best chorus found at 5 min 58.33 sec
# Processing track 3523 of 3932
# Best chorus found at 1 min 32.69 sec
# Processing track 3524 of 3932
# Best chorus found at 1 min 9.47 sec
# Processing track 3525 of 3932
# Best chorus found at 3 min 19.66 sec
# Processing track 3526 of 3932
# Best chorus found at 1 min 48.97 sec
# Processing track 3527 of 3932
# Best chorus found at 2 min 0.50 sec
# Processing track 3528 of 3932
# Best chorus found at 1 min 28.77 sec
# Processing track 3529 of 3932
# Best chorus found at 0 min 54.94 sec
# Processing track 3530 of 3932
# Best chorus found at 3 min 51.80 sec
# Processing track 3531 of 3932
# Best chorus found at 1 min 48.48 sec
# Processing track 3532 of 3932
# Best chorus found at 3 min 12.07 sec
# Processing track 3533 of 3932
# Best chorus found at 1 min 58.33 sec
# Processing track 3534 of 3932
# Best chorus found at 2 min 15.60 sec
# Processing track 3535 of 3932
# Best chorus found at 1 min 8.51 sec
# Processing track 3536 of 3932
# Best chorus found at 1 min 21.73 sec
# Processing track 3537 of 3932
# Best chorus found at 3 min 43.09 sec
# Processing track 3538 of 3932
# Best chorus found at 2 min 13.70 sec
# Processing track 3539 of 3932
# Best chorus found at 2 min 30.65 sec
# Processing track 3540 of 3932
# Best chorus found at 2 min 23.85 sec
# Processing track 3541 of 3932
# Best chorus found at 3 min 4.77 sec
# Processing track 3542 of 3932
# Best chorus found at 1 min 19.69 sec
# Processing track 3543 of 3932
# Best chorus found at 2 min 25.60 sec
# Processing track 3544 of 3932
# Best chorus found at 1 min 23.17 sec
# Processing track 3545 of 3932
# Best chorus found at 3 min 20.80 sec
# Processing track 3546 of 3932
# Best chorus found at 2 min 6.41 sec
# Processing track 3547 of 3932
# Best chorus found at 2 min 6.13 sec
# Processing track 3548 of 3932
# Best chorus found at 3 min 3.26 sec
# Processing track 3549 of 3932
# Best chorus found at 2 min 33.17 sec
# Processing track 3550 of 3932
# Best chorus found at 5 min 37.97 sec
# Processing track 3551 of 3932
# Best chorus found at 5 min 46.44 sec
# Processing track 3552 of 3932
# Best chorus found at 3 min 6.69 sec
# Processing track 3553 of 3932
# Best chorus found at 2 min 37.06 sec
# Processing track 3554 of 3932
# Best chorus found at 1 min 50.86 sec
# Processing track 3555 of 3932
# Best chorus found at 2 min 37.12 sec
# Processing track 3556 of 3932
# Best chorus found at 2 min 52.87 sec
# Processing track 3557 of 3932
# Best chorus found at 2 min 16.53 sec
# Processing track 3558 of 3932
# Best chorus found at 3 min 13.15 sec
# Processing track 3559 of 3932
# Best chorus found at 2 min 5.13 sec
# Processing track 3560 of 3932
# Best chorus found at 1 min 53.87 sec
# Processing track 3561 of 3932
# Best chorus found at 1 min 58.79 sec
# Processing track 3562 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3563 of 3932
# Best chorus found at 1 min 57.93 sec
# Processing track 3564 of 3932
# Best chorus found at 3 min 17.33 sec
# Processing track 3565 of 3932
# Best chorus found at 0 min 36.97 sec
# Processing track 3566 of 3932
# Best chorus found at 2 min 58.95 sec
# Processing track 3567 of 3932
# Best chorus found at 1 min 44.77 sec
# Processing track 3568 of 3932
# Best chorus found at 3 min 47.55 sec
# Processing track 3569 of 3932
# Best chorus found at 3 min 10.37 sec
# Processing track 3570 of 3932
# Best chorus found at 3 min 10.70 sec
# Processing track 3571 of 3932
# Best chorus found at 0 min 50.64 sec
# Processing track 3572 of 3932
# Best chorus found at 2 min 1.64 sec
# Processing track 3573 of 3932
# Best chorus found at 2 min 48.38 sec
# Processing track 3574 of 3932
# Best chorus found at 3 min 20.19 sec
# Processing track 3575 of 3932
# Best chorus found at 2 min 30.09 sec
# Processing track 3576 of 3932
# Best chorus found at 1 min 39.38 sec
# Processing track 3577 of 3932
# Best chorus found at 2 min 14.22 sec
# Processing track 3578 of 3932
# Best chorus found at 2 min 23.68 sec
# Processing track 3579 of 3932
# Best chorus found at 1 min 34.55 sec
# Processing track 3580 of 3932
# Best chorus found at 1 min 53.87 sec
# Processing track 3581 of 3932
# Best chorus found at 4 min 18.32 sec
# Processing track 3582 of 3932
# Best chorus found at 1 min 23.33 sec
# Processing track 3583 of 3932
# Best chorus found at 3 min 33.25 sec
# Processing track 3584 of 3932
# Best chorus found at 1 min 24.11 sec
# Processing track 3585 of 3932
# Best chorus found at 1 min 36.67 sec
# Processing track 3586 of 3932
# Best chorus found at 2 min 58.98 sec
# Processing track 3587 of 3932
# Best chorus found at 3 min 46.92 sec
# Processing track 3588 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3589 of 3932
# Best chorus found at 2 min 2.68 sec
# Processing track 3590 of 3932
# Best chorus found at 3 min 26.30 sec
# Processing track 3591 of 3932
# Best chorus found at 2 min 28.05 sec
# Processing track 3592 of 3932
# Best chorus found at 2 min 28.01 sec
# Processing track 3593 of 3932
# Best chorus found at 2 min 58.62 sec
# Processing track 3594 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3595 of 3932
# Best chorus found at 2 min 33.18 sec
# Processing track 3596 of 3932
# Best chorus found at 1 min 37.68 sec
# Processing track 3597 of 3932
# Best chorus found at 2 min 9.39 sec
# Processing track 3598 of 3932
# Best chorus found at 2 min 33.52 sec
# Processing track 3599 of 3932
# Best chorus found at 2 min 44.85 sec
# Processing track 3600 of 3932
# Best chorus found at 3 min 16.42 sec
# Processing track 3601 of 3932
# Best chorus found at 2 min 13.45 sec
# Processing track 3602 of 3932
# Best chorus found at 2 min 2.76 sec
# Processing track 3603 of 3932
# Best chorus found at 1 min 46.18 sec
# Processing track 3604 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3605 of 3932
# Best chorus found at 1 min 55.68 sec
# Processing track 3606 of 3932
# Best chorus found at 2 min 14.75 sec
# Processing track 3607 of 3932
# Best chorus found at 3 min 13.37 sec
# Processing track 3608 of 3932
# Best chorus found at 2 min 15.02 sec
# Processing track 3609 of 3932
# Best chorus found at 2 min 8.70 sec
# Processing track 3610 of 3932
# Best chorus found at 4 min 5.68 sec
# Processing track 3611 of 3932
# Best chorus found at 0 min 39.38 sec
# Processing track 3612 of 3932
# Best chorus found at 1 min 48.46 sec
# Processing track 3613 of 3932
# Best chorus found at 1 min 35.75 sec
# Processing track 3614 of 3932
# Best chorus found at 2 min 19.13 sec
# Processing track 3615 of 3932
# Best chorus found at 3 min 21.24 sec
# Processing track 3616 of 3932
# Best chorus found at 1 min 36.56 sec
# Processing track 3617 of 3932
# Best chorus found at 1 min 24.89 sec
# Processing track 3618 of 3932
# Best chorus found at 3 min 34.66 sec
# Processing track 3619 of 3932
# Best chorus found at 1 min 8.15 sec
# Processing track 3620 of 3932
# Best chorus found at 3 min 9.29 sec
# Processing track 3621 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3622 of 3932
# Best chorus found at 1 min 54.80 sec
# Processing track 3623 of 3932
# Best chorus found at 2 min 24.89 sec
# Processing track 3624 of 3932
# Best chorus found at 2 min 44.92 sec
# Processing track 3625 of 3932
# Best chorus found at 3 min 39.83 sec
# Processing track 3626 of 3932
# Best chorus found at 3 min 10.40 sec
# Processing track 3627 of 3932
# Best chorus found at 1 min 10.22 sec
# Processing track 3628 of 3932
# Best chorus found at 1 min 45.12 sec
# Processing track 3629 of 3932
# Best chorus found at 1 min 56.76 sec
# Processing track 3630 of 3932
# Best chorus found at 1 min 36.04 sec
# Processing track 3631 of 3932
# Best chorus found at 1 min 24.08 sec
# Processing track 3632 of 3932
# Best chorus found at 2 min 56.74 sec
# Processing track 3633 of 3932
# Best chorus found at 2 min 52.50 sec
# Processing track 3634 of 3932
# Best chorus found at 1 min 37.52 sec
# Processing track 3635 of 3932
# Best chorus found at 2 min 35.97 sec
# Processing track 3636 of 3932
# Best chorus found at 3 min 0.18 sec
# Processing track 3637 of 3932
# Best chorus found at 1 min 43.21 sec
# Processing track 3638 of 3932
# Best chorus found at 2 min 49.93 sec
# Processing track 3639 of 3932
# Best chorus found at 2 min 2.69 sec
# Processing track 3640 of 3932
# Best chorus found at 1 min 23.40 sec
# Processing track 3641 of 3932
# Best chorus found at 3 min 21.55 sec
# Processing track 3642 of 3932
# Best chorus found at 1 min 6.32 sec
# Processing track 3643 of 3932
# Best chorus found at 3 min 2.34 sec
# Processing track 3644 of 3932
# Best chorus found at 3 min 10.37 sec
# Processing track 3645 of 3932
# Best chorus found at 1 min 12.76 sec
# Processing track 3646 of 3932
# Best chorus found at 2 min 42.64 sec
# Processing track 3647 of 3932
# Best chorus found at 1 min 10.95 sec
# Processing track 3648 of 3932
# Best chorus found at 2 min 41.76 sec
# Processing track 3649 of 3932
# Best chorus found at 0 min 54.05 sec
# Processing track 3650 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3651 of 3932
# Best chorus found at 2 min 39.94 sec
# Processing track 3652 of 3932
# Best chorus found at 2 min 10.59 sec
# Processing track 3653 of 3932
# Best chorus found at 4 min 12.04 sec
# Processing track 3654 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3655 of 3932
# Best chorus found at 1 min 35.83 sec
# Processing track 3656 of 3932
# Best chorus found at 2 min 8.69 sec
# Processing track 3657 of 3932
# Best chorus found at 3 min 6.05 sec
# Processing track 3658 of 3932
# Best chorus found at 2 min 9.96 sec
# Processing track 3659 of 3932
# Best chorus found at 2 min 31.76 sec
# Processing track 3660 of 3932
# Best chorus found at 2 min 44.32 sec
# Processing track 3661 of 3932
# Best chorus found at 1 min 58.97 sec
# Processing track 3662 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3663 of 3932
# Best chorus found at 2 min 45.79 sec
# Processing track 3664 of 3932
# Best chorus found at 3 min 44.02 sec
# Processing track 3665 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3666 of 3932
# Best chorus found at 1 min 25.63 sec
# Processing track 3667 of 3932
# Best chorus found at 2 min 28.76 sec
# Processing track 3668 of 3932
# Best chorus found at 1 min 14.47 sec
# Processing track 3669 of 3932
# Best chorus found at 2 min 38.71 sec
# Processing track 3670 of 3932
# Best chorus found at 2 min 45.47 sec
# Processing track 3671 of 3932
# Best chorus found at 1 min 35.81 sec
# Processing track 3672 of 3932
# Best chorus found at 1 min 20.62 sec
# Processing track 3673 of 3932
# Best chorus found at 3 min 4.77 sec
# Processing track 3674 of 3932
# Best chorus found at 1 min 41.88 sec
# Processing track 3675 of 3932
# Best chorus found at 4 min 38.57 sec
# Processing track 3676 of 3932
# Best chorus found at 0 min 50.86 sec
# Processing track 3677 of 3932
# Best chorus found at 3 min 50.34 sec
# Processing track 3678 of 3932
# Best chorus found at 2 min 15.53 sec
# Processing track 3679 of 3932
# Best chorus found at 2 min 10.84 sec
# Processing track 3680 of 3932
# Best chorus found at 1 min 53.46 sec
# Processing track 3681 of 3932
# Best chorus found at 3 min 35.18 sec
# Processing track 3682 of 3932
# Best chorus found at 0 min 58.50 sec
# Processing track 3683 of 3932
# Best chorus found at 2 min 7.92 sec
# ...
# Best chorus found at 2 min 1.11 sec
# Processing track 3731 of 3932
# Best chorus found at 1 min 32.25 sec
# Processing track 3732 of 3932
# Best chorus found at 1 min 23.18 sec
# Processing track 3733 of 3932
# Best chorus found at 1 min 25.42 sec
# Processing track 3734 of 3932
# Best chorus found at 1 min 30.95 sec
# Processing track 3735 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3736 of 3932
# Best chorus found at 1 min 46.72 sec
# Processing track 3737 of 3932
# WARNING: problem with finding chorus: [Errno 2] No such file or directory: '../data/audio_wav/78KNNzCX1AIoph6k7kqipQ.wav', skipping...
# WARNING: file not found: ../data/audio_wav/78KNNzCX1AIoph6k7kqipQ.wav, skipping...
# Processing track 3738 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3739 of 3932
# Best chorus found at 1 min 45.32 sec
# Processing track 3740 of 3932
# Best chorus found at 1 min 24.82 sec
# Processing track 3741 of 3932
# Best chorus found at 1 min 4.25 sec
# Processing track 3742 of 3932
# Best chorus found at 2 min 46.56 sec
# Processing track 3743 of 3932
# Best chorus found at 1 min 25.78 sec
# Processing track 3744 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3745 of 3932
# Best chorus found at 1 min 1.45 sec
# Processing track 3746 of 3932
# Best chorus found at 1 min 40.44 sec
# Processing track 3747 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3748 of 3932
# Best chorus found at 1 min 32.14 sec
# Processing track 3749 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3750 of 3932
# Best chorus found at 2 min 39.57 sec
# Processing track 3751 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3752 of 3932
# Best chorus found at 1 min 35.08 sec
# Processing track 3753 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3754 of 3932
# Best chorus found at 1 min 39.36 sec
# Processing track 3755 of 3932
# Best chorus found at 2 min 34.11 sec
# Processing track 3756 of 3932
# Best chorus found at 2 min 53.21 sec
# Processing track 3757 of 3932
# Best chorus found at 2 min 44.18 sec
# Processing track 3758 of 3932
# Best chorus found at 3 min 26.56 sec
# Processing track 3759 of 3932
# WARNING: problem with finding chorus: [Errno 2] No such file or directory: '../data/audio_wav/0A0IrtCZsJbvHeFMfwNKef.wav', skipping...
# WARNING: file not found: ../data/audio_wav/0A0IrtCZsJbvHeFMfwNKef.wav, skipping...
# Processing track 3760 of 3932
# Best chorus found at 1 min 59.78 sec
# Processing track 3761 of 3932
# Best chorus found at 0 min 33.78 sec
# Processing track 3762 of 3932
# Best chorus found at 2 min 1.24 sec
# Processing track 3763 of 3932
# Best chorus found at 2 min 23.52 sec
# Processing track 3764 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3765 of 3932
# Best chorus found at 1 min 17.23 sec
# Processing track 3766 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3767 of 3932
# Best chorus found at 1 min 46.44 sec
# Processing track 3768 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3769 of 3932
# Best chorus found at 2 min 23.01 sec
# Processing track 3770 of 3932
# Best chorus found at 2 min 14.25 sec
# Processing track 3771 of 3932
# Best chorus found at 3 min 15.05 sec
# Processing track 3772 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3773 of 3932
# Best chorus found at 3 min 54.54 sec
# Processing track 3774 of 3932
# Best chorus found at 1 min 9.46 sec
# Processing track 3775 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3776 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3777 of 3932
# Best chorus found at 1 min 26.01 sec
# Processing track 3778 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3779 of 3932
# Best chorus found at 2 min 57.15 sec
# Processing track 3780 of 3932
# Best chorus found at 2 min 19.09 sec
# Processing track 3781 of 3932
# Best chorus found at 1 min 23.89 sec
# Processing track 3782 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3783 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3784 of 3932
# Best chorus found at 1 min 47.74 sec
# Processing track 3785 of 3932
# Best chorus found at 2 min 33.40 sec
# Processing track 3786 of 3932
# Best chorus found at 2 min 48.42 sec
# Processing track 3787 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3788 of 3932
# Best chorus found at 1 min 48.25 sec
# Processing track 3789 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3790 of 3932
# Best chorus found at 2 min 30.25 sec
# Processing track 3791 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3792 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3793 of 3932
# Best chorus found at 1 min 16.14 sec
# Processing track 3794 of 3932
# Best chorus found at 1 min 51.21 sec
# Processing track 3795 of 3932
# Best chorus found at 1 min 36.15 sec
# Processing track 3796 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3797 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3798 of 3932
# Best chorus found at 2 min 16.16 sec
# Processing track 3799 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3800 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3801 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3802 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3803 of 3932
# Best chorus found at 1 min 41.42 sec
# Processing track 3804 of 3932
# Best chorus found at 2 min 22.66 sec
# Processing track 3805 of 3932
# Best chorus found at 1 min 18.18 sec
# Processing track 3806 of 3932
# Best chorus found at 1 min 32.65 sec
# Processing track 3807 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3808 of 3932
# Best chorus found at 2 min 54.02 sec
# Processing track 3809 of 3932
# Best chorus found at 2 min 11.41 sec
# Processing track 3810 of 3932
# Best chorus found at 1 min 20.96 sec
# Processing track 3811 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3812 of 3932
# Best chorus found at 2 min 4.38 sec
# Processing track 3813 of 3932
# Best chorus found at 2 min 42.72 sec
# Processing track 3814 of 3932
# Best chorus found at 2 min 25.35 sec
# Processing track 3815 of 3932
# Best chorus found at 0 min 51.45 sec
# Processing track 3816 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3817 of 3932
# Best chorus found at 1 min 26.56 sec
# Processing track 3818 of 3932
# Best chorus found at 1 min 14.29 sec
# Processing track 3819 of 3932
# Best chorus found at 2 min 31.86 sec
# Processing track 3820 of 3932
# Best chorus found at 4 min 3.34 sec
# Processing track 3821 of 3932
# Best chorus found at 0 min 58.68 sec
# Processing track 3822 of 3932
# Best chorus found at 2 min 11.13 sec
# Processing track 3823 of 3932
# Best chorus found at 3 min 38.39 sec
# Processing track 3824 of 3932
# Best chorus found at 1 min 38.80 sec
# Processing track 3825 of 3932
# Best chorus found at 1 min 21.88 sec
# Processing track 3826 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3827 of 3932
# Best chorus found at 2 min 55.24 sec
# Processing track 3828 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3829 of 3932
# Best chorus found at 2 min 32.45 sec
# Processing track 3830 of 3932
# Best chorus found at 1 min 30.74 sec
# Processing track 3831 of 3932
# Best chorus found at 2 min 51.98 sec
# Processing track 3832 of 3932
# Best chorus found at 1 min 29.91 sec
# Processing track 3833 of 3932
# Best chorus found at 2 min 56.10 sec
# Processing track 3834 of 3932
# Best chorus found at 3 min 6.69 sec
# Processing track 3835 of 3932
# Best chorus found at 1 min 14.49 sec
# Processing track 3836 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3837 of 3932
# Best chorus found at 2 min 44.40 sec
# Processing track 3838 of 3932
# Best chorus found at 1 min 51.01 sec
# Processing track 3839 of 3932
# Best chorus found at 1 min 30.46 sec
# Processing track 3840 of 3932
# Best chorus found at 1 min 26.17 sec
# Processing track 3841 of 3932
# Best chorus found at 3 min 41.61 sec
# Processing track 3842 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3843 of 3932
# Best chorus found at 2 min 23.53 sec
# Processing track 3844 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3845 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3846 of 3932
# Best chorus found at 1 min 40.09 sec
# Processing track 3847 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3848 of 3932
# Best chorus found at 2 min 0.11 sec
# Processing track 3849 of 3932
# Best chorus found at 2 min 46.07 sec
# Processing track 3850 of 3932
# Best chorus found at 1 min 47.69 sec
# Processing track 3851 of 3932
# Best chorus found at 2 min 55.47 sec
# Processing track 3852 of 3932
# Best chorus found at 2 min 33.53 sec
# Processing track 3853 of 3932
# Best chorus found at 2 min 20.00 sec
# Processing track 3854 of 3932
# Best chorus found at 1 min 6.47 sec
# Processing track 3855 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3856 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3857 of 3932
# Best chorus found at 3 min 17.61 sec
# Processing track 3858 of 3932
# Best chorus found at 1 min 35.48 sec
# Processing track 3859 of 3932
# Best chorus found at 1 min 25.39 sec
# Processing track 3860 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3861 of 3932
# Best chorus found at 2 min 16.81 sec
# Processing track 3862 of 3932
# Best chorus found at 1 min 39.17 sec
# Processing track 3863 of 3932
# Best chorus found at 2 min 56.18 sec
# Processing track 3864 of 3932
# Best chorus found at 2 min 28.79 sec
# Processing track 3865 of 3932
# Best chorus found at 2 min 55.25 sec
# Processing track 3866 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3867 of 3932
# Best chorus found at 2 min 14.23 sec
# Processing track 3868 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3869 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3870 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3871 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3872 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3873 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3874 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3875 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3876 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3877 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3878 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3879 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3880 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3881 of 3932
# Best chorus found at 1 min 57.40 sec
# Processing track 3882 of 3932
# Best chorus found at 1 min 24.52 sec
# Processing track 3883 of 3932
# Best chorus found at 1 min 37.71 sec
# WARNING: file loading timed out for ../data/audio_wav/6chK7QlDILELjoh0I98KpW.wav, skipping...
# Processing track 3884 of 3932
# Best chorus found at 1 min 8.71 sec
# Processing track 3885 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3886 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3887 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3888 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3889 of 3932
# Best chorus found at 1 min 3.16 sec
# Processing track 3890 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3891 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3892 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3893 of 3932
# Best chorus found at 2 min 3.31 sec
# Processing track 3894 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3895 of 3932
# Best chorus found at 1 min 34.69 sec
# Processing track 3896 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3897 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3898 of 3932
# Best chorus found at 1 min 46.17 sec
# Processing track 3899 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3900 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3901 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3902 of 3932
# Best chorus found at 1 min 30.39 sec
# Processing track 3903 of 3932
# Best chorus found at 1 min 22.43 sec
# Processing track 3904 of 3932
# Best chorus found at 1 min 42.12 sec
# Processing track 3905 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3906 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3907 of 3932
# Best chorus found at 1 min 25.04 sec
# Processing track 3908 of 3932
# Best chorus found at 2 min 18.95 sec
# Processing track 3909 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3910 of 3932
# Best chorus found at 1 min 43.98 sec
# Processing track 3911 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3912 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3913 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3914 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3915 of 3932
# Best chorus found at 4 min 43.72 sec
# Processing track 3916 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3917 of 3932
# WARNING: problem with finding chorus: Timeout loading audio file, skipping...
# Processing track 3918 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3919 of 3932
# Best chorus found at 2 min 20.95 sec
# Processing track 3920 of 3932
# Best chorus found at 3 min 58.70 sec
# Processing track 3921 of 3932
# Best chorus found at 1 min 55.47 sec
# Processing track 3922 of 3932
# Best chorus found at 1 min 30.39 sec
# Processing track 3923 of 3932
# Best chorus found at 3 min 10.03 sec
# Processing track 3924 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3925 of 3932
# Best chorus found at 2 min 5.31 sec
# Processing track 3926 of 3932
# Best chorus found at 1 min 53.10 sec
# Processing track 3927 of 3932
# No choruses were detected. Try a smaller search duration
# Processing track 3928 of 3932
# Best chorus found at 1 min 56.10 sec
# Processing track 3929 of 3932
# Best chorus found at 1 min 25.63 sec
# Processing track 3930 of 3932
# Best chorus found at 1 min 26.15 sec
